# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
feedburner = feedparser.parse(url)
print(feedburner)
# Out:
# {'feed': {'title': "All - O'Reilly Media", 'title_detail': {'type': 'text/plain', 'language': None, 'base': 'http://feeds.feedburner.com/oreilly/radar/atom', 'value': "All - O'Reilly Media"}, 'id': 'https://www.oreilly.com', 'guidislink': True, 'link': 'https://www.oreilly.com', 'updated': '2019-02-06T10:57:17Z', 'updated_parsed': time.struct_time(tm_year=2019, tm_mon=2, tm_mday=6, tm_hour=10, tm_min=57, tm_sec=17, tm_wday=2, tm_yday=37, tm_isdst=0), 'subtitle': 'All of our Ideas and Learning material from all of our topics.', 'subtitle_detail': {'type': 'text/plain', 'language': None, 'base': 'http://feeds.feedburner.com/oreilly/radar/atom', 'value': 'All of our Ideas and Learning material from all of our topics.'}, 'links': [{'href': 'https://www.oreilly.com', 'rel': 'alternate', 'type': 'text/html'}, {'rel': 'self', 'type': 'application/atom+xml', 'href': 'http://feeds.feedburner.com/oreilly/radar/atom'}, {'rel': 'hub', 'href': 'http://pubsubhubbub.appspot.com/', 'type': 'text/htm
# ...

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
feedburner.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
feedburner.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'id', 'guidislink', 'link', 'updated', 'updated_parsed', 'subtitle', 'subtitle_detail', 'links', 'authors', 'author_detail', 'author', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
print(feedburner.feed.title)
print(feedburner.feed.subtitle)
print(feedburner.feed.author)
print(feedburner.feed.link)
# Out:
# All - O'Reilly Media
# All of our Ideas and Learning material from all of our topics.
# O'Reilly Media
# https://www.oreilly.com

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(feedburner.entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
feedburner.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'updated', 'updated_parsed', 'id', 'guidislink', 'link', 'content', 'summary', 'links', 'authors', 'author_detail', 'author', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
entries = []
for i in range(len(feedburner.entries)):
    entries.append(feedburner.entries[i].title)
print(entries)
len(entries)
# Out:
# ['The future of cloud-native programming', "Highlights from the O'Reilly Software Architecture Conference in New York 2019", 'Career advice for architects', 'From the trenches: An interview with Mark Richards', 'Four short links: 5 February 2019', '3 emerging trends tech leaders should watch', 'Artificial intelligence and machine learning adoption in European enterprise', 'Reinforcement learning for the birds', 'Four short links: 4 February 2019', 'Four short links: 1 February 2019', 'Using machine learning and analytics to attract and retain employees', 'Four short links: 31 January 2019', 'Four short links: 30 January 2019', 'How companies are building sustainable AI and ML initiatives', 'Four short links: 29 January 2019', 'Four short links: 28 January 2019', 'Rethinking informed consent', 'Four short links: 25 January 2019', 'Four short links: 24 January 2019', '7 web dev trends on our radar', 'Four short links: 23 January 2019', 'The trinity of errors in financial models: An int
# ...

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
pct = 0
for i in entries:
    if str.startswith(i, 'Four short links'):
        pct += 1
percentage = pct/len(entries)*100
#print(pct)
print(percentage)
# Out:
# 58.333333333333336

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(feedburner.entries)
df.head(15)
# Out:
#                        author                          author_detail  \
# 0                 Tamar Eilam                {'name': 'Tamar Eilam'}
# 1                  Mac Slocum                 {'name': 'Mac Slocum'}
# 2                  Trisha Gee                 {'name': 'Trisha Gee'}
# 3    Neal Ford, Mark Richards   {'name': 'Neal Ford, Mark Richards'}
# 4              Nat Torkington             {'name': 'Nat Torkington'}
# 5   Roger Magoulas, Andy Oram  {'name': 'Roger Magoulas, Andy Oram'}
# 6                  Ben Lorica                 {'name': 'Ben Lorica'}
# 7               Mike Loukides              {'name': 'Mike Loukides'}
# 8              Nat Torkington             {'name': 'Nat Torkington'}
# 9              Nat Torkington             {'name': 'Nat Torkington'}
# 10                 Ben Lorica                 {'name': 'Ben Lorica'}
# 11             Nat Torkington             {'name': 'Nat Torkington'}
# 12             Nat Torkington             {'name': 'Nat Torkington'}
# ...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
authors = df.groupby('author', as_index=False).agg({'title':'count'})
authors.columns = ['author', 'entries']
authors.sort_values('entries', ascending=False)
# Out:
#                          author  entries
# 10               Nat Torkington       35
# 0                    Ben Lorica        7
# 9                 Mike Loukides        2
# 3                Deepak Kanungo        1
# 4                     Jenn Webb        1
# 5              Jennifer Pollock        1
# 6                   Laurent Gil        1
# 7      Liam Li, Ameet Talwalkar        1
# 8                    Mac Slocum        1
# 1     Ben Lorica, Mike Loukides        1
# 2       Ben Lorica, Paco Nathan        1
# 11     Neal Ford, Mark Richards        1
# 12  Nikki McDonald, John Devins        1
# 13    Roger Magoulas, Andy Oram        1
# 14                  Tamar Eilam        1
# 15                 Tim O'Reilly        1
# 16                   Trisha Gee        1
# 17    Tyler Ortman, Jeff Bleiel        1

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
df['title_length'] = df['title'].apply(len)
df[['title','author','title_length']].sort_values('title_length', ascending=False)
# Out:
#                                                 title  \
# 21  The trinity of errors in financial models: An ...
# 1   Highlights from the O'Reilly Software Architec...
# 6   Artificial intelligence and machine learning a...
# 46  250+ live online training courses opened for J...
# 10  Using machine learning and analytics to attrac...
# 13  How companies are building sustainable AI and ...
# 28  What lies ahead for Python, Java, Go, C#, Kotl...
# 23  9 trends to watch in systems engineering and o...
# 43  In the age of AI, fundamental value resides in...
# 3   From the trenches: An interview with Mark Rich...
# 26  How machine learning impacts information security
# 5         3 emerging trends tech leaders should watch
# 55           Trends in data, machine learning, and AI
# 0              The future of cloud-native programming
# 7                Reinforcement learning for the birds
# 57                What is neural architecture search?
# ...

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
import re
ml = []
# for i in range(len(entries)):
if df['summary'].str.contains('machine learning').any():
    print('hola')
#     ml.append(df['title'])

#print(ml)
# Out:
# hola
